# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('Final Influencers data.csv',encoding= 'unicode_escape')

# %%
df
# Out:
#          Name_of_Influencer     Insta_Handle  Q_Score Followers Avg_Likes  \
# 0     Priyanka Chopra Jonas   priyankachopra     9.51     79.9m      1.3m
# 1           Shraddha Kapoor   shraddhakapoor     9.46     73.3m      1.1m
# 2               Neha Kakkar       nehakakkar     9.34     70.3m      609k
# 3          Deepika Padukone  deepikapadukone     9.45     67.7m        1m
# 4                Alia Bhatt       aliaabhatt     9.99     66.7m      3.2m
# ...                     ...              ...      ...       ...       ...
# 6496            Ali Berrada      ali_berrada     5.32       20k       112
# 6497          Apsara Mishra     apsaramishra     4.13       20k        38
# 6498         Anagha Godbole     saffrontouch     5.76       20k       158
# 6499          True Elements    true.elements     5.66       20k       154
# 6500             Kishu Jain      retardchick     7.28       20k       785
#
#      Avg_Views Engagement_Ratio   Location                   Categories
# ...

# %%
df.isnull().sum()
# Out:
# Name_of_Influencer    0
# Insta_Handle          0
# Q_Score               0
# Followers             0
# Avg_Likes             0
# Avg_Views             0
# Engagement_Ratio      0
# Location              0
# Categories            0
# dtype: int64

# %%
df
# Out:
#          Name_of_Influencer     Insta_Handle  Q_Score Followers Avg_Likes  \
# 0     Priyanka Chopra Jonas   priyankachopra     9.51     79.9m      1.3m
# 1           Shraddha Kapoor   shraddhakapoor     9.46     73.3m      1.1m
# 2               Neha Kakkar       nehakakkar     9.34     70.3m      609k
# 3          Deepika Padukone  deepikapadukone     9.45     67.7m        1m
# 4                Alia Bhatt       aliaabhatt     9.99     66.7m      3.2m
# ...                     ...              ...      ...       ...       ...
# 6496            Ali Berrada      ali_berrada     5.32       20k       112
# 6497          Apsara Mishra     apsaramishra     4.13       20k        38
# 6498         Anagha Godbole     saffrontouch     5.76       20k       158
# 6499          True Elements    true.elements     5.66       20k       154
# 6500             Kishu Jain      retardchick     7.28       20k       785
#
#      Avg_Views Engagement_Ratio   Location                   Categories
# ...

# %%
df.head()
# Out:
#       Name_of_Influencer     Insta_Handle  Q_Score Followers Avg_Likes  \
# 0  Priyanka Chopra Jonas   priyankachopra     9.51     79.9m      1.3m
# 1        Shraddha Kapoor   shraddhakapoor     9.46     73.3m      1.1m
# 2            Neha Kakkar       nehakakkar     9.34     70.3m      609k
# 3       Deepika Padukone  deepikapadukone     9.45     67.7m        1m
# 4             Alia Bhatt       aliaabhatt     9.99     66.7m      3.2m
#
#   Avg_Views Engagement_Ratio Location                  Categories
# 0      3.6m            1.61%    India  Arts & EntertainmentMovies
# 1      1.3m            1.48%    India  Arts & EntertainmentMovies
# 2        2m            0.87%   Mumbai  Arts & EntertainmentMovies
# 3    893.4k            1.55%    India  Arts & EntertainmentMovies
# 4      4.8m            4.77%    India  Arts & EntertainmentMovies

# %%
df.tail()
# Out:
#      Name_of_Influencer   Insta_Handle  Q_Score Followers Avg_Likes Avg_Views  \
# 6496        Ali Berrada    ali_berrada     5.32       20k       112       649
# 6497      Apsara Mishra   apsaramishra     4.13       20k        38       525
# 6498     Anagha Godbole   saffrontouch     5.76       20k       158      2.3k
# 6499      True Elements  true.elements     5.66       20k       154       393
# 6500         Kishu Jain    retardchick     7.28       20k       785         0
#
#      Engagement_Ratio   Location                   Categories
# 6496            0.57%      India                       Travel
# 6497            0.20%     Mumbai  Family & ParentingLifestyle
# 6498            0.85%    Solapur                 Food & Drink
# 6499            0.79%       Pune                 Food & Drink
# 6500            4.00%  Rajasthan        TechnologyProgramming

# %%
df['Categories'].nunique()
# Out:
# 214

# %%
df.corr()
# Out:
#          Q_Score
# Q_Score      1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6501 entries, 0 to 6500
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name_of_Influencer  6501 non-null   object
#  1   Insta_Handle        6501 non-null   object
#  2   Q_Score             6501 non-null   float64
#  3   Followers           6501 non-null   object
#  4   Avg_Likes           6501 non-null   object
#  5   Avg_Views           6501 non-null   object
#  6   Engagement_Ratio    6501 non-null   object
#  7   Location            6501 non-null   object
#  8   Categories          6501 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 457.2+ KB

# %%
df['Categories'].unique()
# Out:
# array(['Arts & EntertainmentMovies', 'Arts & EntertainmentLifestyle',
#        'Arts & EntertainmentDance', 'TelevisionArts & Entertainment',
#        'Arts & EntertainmentMusic', 'Arts & Entertainment',
#        'Arts & EntertainmentTelevision', 'MoviesArts & Entertainment',
#        'Arts & EntertainmentGaming', 'Health & WellnessFitness',
#        'Arts & EntertainmentHumor / Comedy',
#        'Arts & EntertainmentLiterature',
#        'Style & FashionArts & Entertainment', 'MusicMovies',
#        'DanceArts & Entertainment', 'Arts & EntertainmentStyle & Fashion',
#        'Home DecorArts & Entertainment', 'MusicArts & Entertainment',
#        'LifestyleDance', 'SportsArts & Entertainment',
#        'Arts & EntertainmentPhotography', 'Arts & EntertainmentBlogging',
#        'TravelArts & Entertainment', 'BeautyDance',
#        'LifestyleArts & Entertainment', 'Arts & EntertainmentFitness',
#        'Arts & EntertainmentHealth & Wellness',
# ...

# %%
category=df['Categories']

# %%
ang=df['Categories'].value_counts()
ang.head(20)
#sns.countplot(df['Category'])
# Out:
# Arts & EntertainmentMovies             1321
# Food & Drink                            518
# LifestyleStyle & Fashion                486
# Style & FashionClothing                 364
# Arts & Entertainment                    360
# Arts & EntertainmentMusic               231
# Style & FashionBeauty                   227
# Arts & EntertainmentTelevision          203
# Travel                                  182
# Arts & EntertainmentPhotography         167
# Family & Parenting                      164
# SportsCricket                           127
# Style & Fashion                         126
# Arts & EntertainmentLiterature          116
# Style & FashionLifestyle                110
# LifestyleFood & Drink                    86
# Arts & EntertainmentStyle & Fashion      86
# LifestyleTravel                          77
# Photography                              77
# Arts & EntertainmentDance                69
# Name: Categories, dtype: int64

# %%
Arts & EntertainmentMovies         
Food & Drink    
LifestyleStyle & Fashion
Travel
Family & Parenting
SportsCricket 
photography
music

# %%
df['Location'].nunique()
# Out:
# 207

# %%
df['Location'].unique()
# Out:
# array(['India', 'Mumbai', 'Delhi', 'Bengaluru', 'Hyderabad', 'Chandigarh',
#        'Chennai', 'Kerala', 'Lucknow', 'Mohali', 'Assam', 'Kolkata',
#        'Punjab', 'New Delhi', 'Bihar', 'Ludhiana', 'Goa', 'Surat', 'Pune',
#        'Gurgaon', 'Bihar Sharif', 'Vasco', 'West Bengal', 'Jaipur',
#        'Madanapalle', 'Ahmedabad', 'Kochi', 'Ambala', 'Nainital',
#        'Indore', 'Amritsar', 'Karnal', 'Kannur', 'Vadodara', 'Jalandhar',
#        'Bhavnagar', 'Bareilly', 'Amalapuram', 'Meerut', 'Karnataka',
#        'Nashik', 'Mangalore', 'Nagpur', 'Visakhapatnam', 'Ghaziabad',
#        'Sangrur', 'Mysore', 'Telangana', 'Alappuzha', 'Gorakhpur',
#        'Addanki', 'Aurangabad', 'Hisar', 'Bhandup', 'Guwahati',
#        'Varanasi', 'Ujjain', 'Shillong', 'Andhra Pradesh', 'Culver City',
#        'Haryana', 'Gujarat', 'Dehradun', 'Odisha', 'Nadiad', 'Patiala',
#        'Uttar Pradesh', 'Jamshedpur', 'Tamil Nadu', 'Godhra', 'Nalagarh',
# ...

# %%
df['Location'].value_counts()
# Out:
# India        1905
# Mumbai       1559
# Delhi         480
# New Delhi     427
# Bengaluru     363
#              ...
# Silchar         1
# Palakkad        1
# Addanki         1
# Vesava          1
# Solapur         1
# Name: Location, Length: 207, dtype: int64

# %%
sns.countplot(df['Location'])
# Out:
# <AxesSubplot:xlabel='Location', ylabel='count'>

# %%
df['Engagement_Ratio']
# Out:
# 0       1.61%
# 1       1.48%
# 2       0.87%
# 3       1.55%
# 4       4.77%
#         ...
# 6496    0.57%
# 6497    0.20%
# 6498    0.85%
# 6499    0.79%
# 6500    4.00%
# Name: Engagement_Ratio, Length: 6501, dtype: object

# %%
df['Engagement_Ratio'] = df['Engagement_Ratio'].str.replace('%', '')
df['Engagement_Ratio'] = df['Engagement_Ratio'].astype(float)

# %%
df['Engagement_Ratio']
# Out:
# 0       1.61
# 1       1.48
# 2       0.87
# 3       1.55
# 4       4.77
#         ...
# 6496    0.57
# 6497    0.20
# 6498    0.85
# 6499    0.79
# 6500    4.00
# Name: Engagement_Ratio, Length: 6501, dtype: float64

# %%
df['Engagement_Ratio'].mean()
# Out:
# 2.132458083371796

# %%
df['Engagement_Ratio'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
value=df['Engagement_Ratio'].mode()

# %%
value.value_counts()
# Out:
# 0.0    1
# dtype: int64

# %%
df['Engagement_Ratio'].median()
# Out:
# 1.09

# %%
df['Avg_Likes'].value_counts()
# Out:
# 0         716
# 1k        115
# 1.2k       96
# 1.1k       90
# 1.3k       81
#          ...
# 27k         1
# 65.4k       1
# 114.7k      1
# 59.1k       1
# 785         1
# Name: Avg_Likes, Length: 1595, dtype: int64

# %%
df
# Out:
#          Name_of_Influencer     Insta_Handle  Q_Score Followers Avg_Likes  \
# 0     Priyanka Chopra Jonas   priyankachopra     9.51     79.9m      1.3m
# 1           Shraddha Kapoor   shraddhakapoor     9.46     73.3m      1.1m
# 2               Neha Kakkar       nehakakkar     9.34     70.3m      609k
# 3          Deepika Padukone  deepikapadukone     9.45     67.7m        1m
# 4                Alia Bhatt       aliaabhatt     9.99     66.7m      3.2m
# ...                     ...              ...      ...       ...       ...
# 6496            Ali Berrada      ali_berrada     5.32       20k       112
# 6497          Apsara Mishra     apsaramishra     4.13       20k        38
# 6498         Anagha Godbole     saffrontouch     5.76       20k       158
# 6499          True Elements    true.elements     5.66       20k       154
# 6500             Kishu Jain      retardchick     7.28       20k       785
#
#      Avg_Views  Engagement_Ratio   Location                   Categories
# ...

# %%
df['Followers'].value_counts()
# Out:
# 1m        75
# 1.1m      71
# 1.2m      62
# 0.9m      56
# 1.4m      42
#           ..
# 714.8k     1
# 707.5k     1
# 707.4k     1
# 705k       1
# 79.9m      1
# Name: Followers, Length: 2650, dtype: int64

# %%
df.columns = map(lambda s:s.strip(),df.columns)

# %%
df
# Out:
#          Name_of_Influencer     Insta_Handle  Q_Score Followers Avg_Likes  \
# 0     Priyanka Chopra Jonas   priyankachopra     9.51     79.9m      1.3m
# 1           Shraddha Kapoor   shraddhakapoor     9.46     73.3m      1.1m
# 2               Neha Kakkar       nehakakkar     9.34     70.3m      609k
# 3          Deepika Padukone  deepikapadukone     9.45     67.7m        1m
# 4                Alia Bhatt       aliaabhatt     9.99     66.7m      3.2m
# ...                     ...              ...      ...       ...       ...
# 6496            Ali Berrada      ali_berrada     5.32       20k       112
# 6497          Apsara Mishra     apsaramishra     4.13       20k        38
# 6498         Anagha Godbole     saffrontouch     5.76       20k       158
# 6499          True Elements    true.elements     5.66       20k       154
# 6500             Kishu Jain      retardchick     7.28       20k       785
#
#      Avg_Views  Engagement_Ratio   Location                   Categories
# ...

# %%
df['Avg_Views'].value_counts()
# Out:
# 0         552
# 1k         63
# 1.9k       60
# 1.1k       59
# 2.5k       57
#          ...
# 331.3k      1
# 67.2k       1
# 87.9k       1
# 216.6k      1
# 118         1
# Name: Avg_Views, Length: 1838, dtype: int64

# %%
df['Avg_Likes'].value_counts()
# Out:
# 0         716
# 1k        115
# 1.2k       96
# 1.1k       90
# 1.3k       81
#          ...
# 27k         1
# 65.4k       1
# 114.7k      1
# 59.1k       1
# 785         1
# Name: Avg_Likes, Length: 1595, dtype: int64

# %%
df['Followers'].value_counts()
# Out:
# 1m        75
# 1.1m      71
# 1.2m      62
# 0.9m      56
# 1.4m      42
#           ..
# 714.8k     1
# 707.5k     1
# 707.4k     1
# 705k       1
# 79.9m      1
# Name: Followers, Length: 2650, dtype: int64

# %%
df['Q_Score'].value_counts()
# Out:
# 2.00    261
# 9.20    173
# 7.60    138
# 9.21    110
# 7.62    102
#        ...
# 9.49      1
# 9.44      1
# 5.04      1
# 5.50      1
# 5.49      1
# Name: Q_Score, Length: 539, dtype: int64

# %%
df['Insta_Handle'].value_counts()
# Out:
# aarushiduttaofficial      3
# ____.dreamcatcher.____    3
# meenalshahofficial        3
# aadilkhann                3
# iamskychauhan             3
#                          ..
# pehchan.music             1
# pulkitkochar              1
# eccomics                  1
# onewordepic               1
# retardchick               1
# Name: Insta_Handle, Length: 6074, dtype: int64

# %%
repeatedinsta=df[df['Insta_Handle']=='aarushiduttaofficial']
repeatedinsta
# Out:
#      Name_of_Influencer          Insta_Handle  Q_Score Followers Avg_Likes  \
# 753       Aarushi Dutta  aarushiduttaofficial     9.03      0.9m     41.5k
# 2649      Aarushi Dutta  aarushiduttaofficial     9.03      0.9m     41.5k
# 4179      Aarushi Dutta  aarushiduttaofficial     9.03      0.9m     41.5k
#
#      Avg_Views  Engagement_Ratio Location        Categories
# 753      49.6k              4.44    Delhi  FitnessLifestyle
# 2649     49.6k              4.44    Delhi  FitnessLifestyle
# 4179     49.6k              4.44    Delhi  FitnessLifestyle

# %%
repeatedinsta=df[df['Insta_Handle']=='meenalshahofficial']
repeatedinsta
# Out:
#      Name_of_Influencer        Insta_Handle  Q_Score Followers Avg_Likes  \
# 1661        Meenal Shah  meenalshahofficial     8.02    126.3k      5.7k
# 3110        Meenal Shah  meenalshahofficial     8.02    126.3k      5.7k
# 4819        Meenal Shah  meenalshahofficial     8.02    126.3k      5.7k
#
#      Avg_Views  Engagement_Ratio Location                 Categories
# 1661     32.2k              4.58   Mumbai  Arts & EntertainmentDance
# 3110     32.2k              4.58   Mumbai  Arts & EntertainmentDance
# 4819     32.2k              4.58   Mumbai  Arts & EntertainmentDance

# %% [markdown]
# **So from here we got that are lots of people whose with same insta id there are duplicate values**

# %%
df['Name_of_Influencer'].value_counts()
# Out:
# Neha Sharma           4
# Indian Photography    4
# Aarushi Dutta         3
# ????????????          3
# Yash                  3
#                      ..
# Aerreo                1
# Romit Raj Prasher     1
# Pehchan Music         1
# Pulkit Kochar         1
# Kishu Jain            1
# Name: Name_of_Influencer, Length: 6007, dtype: int64

# %%
repeatedname=df[df['Name_of_Influencer']=='Yash']
repeatedname
# Out:
#      Name_of_Influencer   Insta_Handle  Q_Score Followers Avg_Likes Avg_Views  \
# 81                 Yash  thenameisyash     9.49     10.8m      1.2m      2.5m
# 644                Yash   yashdasgupta     8.57      1.2m     18.4k     75.8k
# 4151               Yash   yashdasgupta     8.57      1.2m     18.4k     75.8k
#
#       Engagement_Ratio Location                  Categories
# 81               11.17    India  Arts & EntertainmentMovies
# 644               1.64  Kolkata  MoviesArts & Entertainment
# 4151              1.64  Kolkata  MoviesArts & Entertainment

# %%
repeatedname=df[df['Name_of_Influencer']=='Neha Sharma']
repeatedname
# Out:
#      Name_of_Influencer        Insta_Handle  Q_Score Followers Avg_Likes  \
# 61          Neha Sharma  nehasharmaofficial     9.24     14.6m    223.1k
# 4253        Neha Sharma       fitnessbyneha     7.97    630.9k      5.1k
# 4885        Neha Sharma    hungrydilliwaali     2.00    114.3k         0
# 5894        Neha Sharma          nsnsneha87     6.60     35.8k       411
#
#      Avg_Views  Engagement_Ratio     Location                  Categories
# 61      269.4k              1.54        India  Arts & EntertainmentMovies
# 4253       12k              0.83       Jaipur    FitnessHealth & Wellness
# 4885         0              0.00        India                Food & Drink
# 5894      6.5k              1.19  Uttarakhand          Family & Parenting

# %% [markdown]
# **So from here we got that may be there name are same but they are different peoples. so that's why we will not drop duplicate values according to name we will drop duplicate values according to insta_handle.**

# %%
df
# Out:
#          Name_of_Influencer     Insta_Handle  Q_Score Followers Avg_Likes  \
# 0     Priyanka Chopra Jonas   priyankachopra     9.51     79.9m      1.3m
# 1           Shraddha Kapoor   shraddhakapoor     9.46     73.3m      1.1m
# 2               Neha Kakkar       nehakakkar     9.34     70.3m      609k
# 3          Deepika Padukone  deepikapadukone     9.45     67.7m        1m
# 4                Alia Bhatt       aliaabhatt     9.99     66.7m      3.2m
# ...                     ...              ...      ...       ...       ...
# 6496            Ali Berrada      ali_berrada     5.32       20k       112
# 6497          Apsara Mishra     apsaramishra     4.13       20k        38
# 6498         Anagha Godbole     saffrontouch     5.76       20k       158
# 6499          True Elements    true.elements     5.66       20k       154
# 6500             Kishu Jain      retardchick     7.28       20k       785
#
#      Avg_Views  Engagement_Ratio   Location                   Categories
# ...

# %%
df.shape
# Out:
# (6501, 9)

# %%
df['Name_of_Influencer'].value_counts()
# Out:
# Neha Sharma           4
# Indian Photography    4
# Aarushi Dutta         3
# ????????????          3
# Yash                  3
#                      ..
# Aerreo                1
# Romit Raj Prasher     1
# Pehchan Music         1
# Pulkit Kochar         1
# Kishu Jain            1
# Name: Name_of_Influencer, Length: 6007, dtype: int64

# %%
df.shape
# Out:
# (6501, 9)

# %%
df['Name_of_Influencer'].nunique()
# Out:
# 6007

# %%
df['Insta_Handle'].nunique()
# Out:
# 6074

# %%
df["Followers"]=df["Followers"].replace({"k":"*1e3", "m":"*1e6"}, regex=True).map(pd.eval).astype(int)
df["Avg_Likes"]=df["Avg_Likes"].replace({"k":"*1e3", "m":"*1e6"}, regex=True).map(pd.eval).astype(int)
df["Avg_Views"]=df["Avg_Views"].replace({"k":"*1e3", "m":"*1e6"}, regex=True).map(pd.eval).astype(int)

# %%
df
# Out:
#          Name_of_Influencer     Insta_Handle  Q_Score  Followers  Avg_Likes  \
# 0     Priyanka Chopra Jonas   priyankachopra     9.51   79900000    1300000
# 1           Shraddha Kapoor   shraddhakapoor     9.46   73300000    1100000
# 2               Neha Kakkar       nehakakkar     9.34   70300000     609000
# 3          Deepika Padukone  deepikapadukone     9.45   67700000    1000000
# 4                Alia Bhatt       aliaabhatt     9.99   66700000    3200000
# ...                     ...              ...      ...        ...        ...
# 6496            Ali Berrada      ali_berrada     5.32      20000        112
# 6497          Apsara Mishra     apsaramishra     4.13      20000         38
# 6498         Anagha Godbole     saffrontouch     5.76      20000        158
# 6499          True Elements    true.elements     5.66      20000        154
# 6500             Kishu Jain      retardchick     7.28      20000        785
#
# ...

# %%
df.nunique()
# Out:
# Name_of_Influencer    6007
# Insta_Handle          6074
# Q_Score                539
# Followers             2650
# Avg_Likes             1595
# Avg_Views             1838
# Engagement_Ratio       917
# Location               207
# Categories             214
# dtype: int64

# %%
df.corr()
# Out:
#                    Q_Score  Followers  Avg_Likes  Avg_Views  Engagement_Ratio
# Q_Score           1.000000   0.204258   0.244593   0.171624          0.414032
# Followers         0.204258   1.000000   0.761148   0.517456          0.025111
# Avg_Likes         0.244593   0.761148   1.000000   0.551809          0.202559
# Avg_Views         0.171624   0.517456   0.551809   1.000000          0.124431
# Engagement_Ratio  0.414032   0.025111   0.202559   0.124431          1.000000

# %%
df['Avg_Likes'].isnull().value_counts()
# Out:
# False    6501
# Name: Avg_Likes, dtype: int64

# %%
#df1['Avg Views'] = df1['Avg Views'].str.replace('m', '000000')
#df1['Avg Views'] = df1['Avg Views'].str.replace('k', '000')
#df1['Avg Views'] = df1['Avg Views'].astype(float)

# %%
nulllikes=df[df['Avg_Likes']==0]
nulllikes
# Out:
#               Name_of_Influencer         Insta_Handle  Q_Score  Followers  \
# 58                 Ileana D'Cruz      ileana_official     7.13   14800000
# 90                 Vishal Pandey      vishalpandey_21     7.60   10300000
# 119              Krystle D'souza        krystledsouza     6.12    7500000
# 176               Hiphop Tamizha        hiphoptamizha     6.38    5200000
# 187            Bhavin Bhanushali           bhavin_333     7.62    4900000
# ...                          ...                  ...      ...        ...
# 6456                Meaty Mumbai          meatymumbai     2.00      20700
# 6470                  Mehak Jain       myclumsycloset     2.00      20500
# 6471  The Heaven Slice | Ruksana      the_heavenslice     2.24      20500
# 6480       VADODARA FOOD BLOGGER  foodies.of.vadodara     2.00      20300
# 6493             The Mumbai Vibe        kathleenmurze     2.00      20100
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# ...

# %%
nullviews=df[df['Avg_Views']==0]
nullviews
# Out:
#            Name_of_Influencer      Insta_Handle  Q_Score  Followers  \
# 203                Tia Bajpai         tiabajpai     9.03    4700000
# 246             Poonam Pandey     ipoonampandey     2.00    3700000
# 255                Aamir Khan        _aamirkhan     9.25    3600000
# 373                    Funcho            funcho     9.24    2300000
# 405                Upen Patel    upenpatelworld     8.83    2100000
# ...                       ...               ...      ...        ...
# 6485           Doruk Canbilen            dorukc     5.52      20200
# 6491  Jasmine | Student Guide   jasminesachdeva     7.36      20100
# 6492            Wishingmirror  thewishingmirror     6.12      20100
# 6493          The Mumbai Vibe     kathleenmurze     2.00      20100
# 6500               Kishu Jain       retardchick     7.28      20000
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# 203       41800          0              0.89      India
# ...

# %%
nullengagement=df[df['Engagement_Ratio']==0.00]
nullengagement
# Out:
#          Name_of_Influencer         Insta_Handle  Q_Score  Followers  \
# 58            Ileana D'Cruz      ileana_official     7.13   14800000
# 119         Krystle D'souza        krystledsouza     6.12    7500000
# 246           Poonam Pandey        ipoonampandey     2.00    3700000
# 262              Ravi Dubey        ravidubey2312     5.54    3500000
# 328        Rithvik Dhanjani            rithvik_d     4.54    2800000
# ...                     ...                  ...      ...        ...
# 6437        Aurakasihlovers             amoresfa     2.00      21200
# 6456           Meaty Mumbai          meatymumbai     2.00      20700
# 6470             Mehak Jain       myclumsycloset     2.00      20500
# 6480  VADODARA FOOD BLOGGER  foodies.of.vadodara     2.00      20300
# 6493        The Mumbai Vibe        kathleenmurze     2.00      20100
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# 58            0     405700               0.0      India
# ...

# %%
nullengagement1=df[df['Engagement_Ratio']>=5.0]
nullengagement1
# Out:
#                 Name_of_Influencer                  Insta_Handle  Q_Score  \
# 27               Rashmika Mandanna             rashmika_mandanna     9.79
# 29                  Shah Rukh Khan                        iamsrk     9.70
# 36            Samantha Ruth Prabhu        samantharuthprabhuoffl     9.56
# 48                      Allu Arjun               alluarjunonline     9.59
# 54                           Fgdfg                   carryminati     9.56
# ...                            ...                           ...      ...
# 6447  Malayalam Tech - ?????? ????         malayalamtechofficial     7.60
# 6449          Sunfeast DarkFantasy           sunfeastdarkfantasy     8.71
# 6472    Rohit Nagwekar Photography  weddingzest_by_rohitnagwekar     7.62
# 6487              SAMRAT SHUKLA ??             samratkipathshala     7.71
# 6488                Anshul Keswani              the.carving.lens     7.61
#
#       Followers  Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# ...

# %%
nullengagement2=df[df['Engagement_Ratio']>=20.00]
nullengagement2
# Out:
#                   Name_of_Influencer           Insta_Handle  Q_Score  \
# 221                          Dhanush           dhanushkraja     9.47
# 297             Kalyani Priyadarshan    kalyanipriyadarshan     9.36
# 351                   Radhika Pandit       iamradhikapandit     9.32
# 1181           Tarini Shah | Blogger            tarini_shah     9.20
# 1271                          Ananya           ananyaongram     9.20
# 1370                    Khushi Hegde            khushihegde     9.20
# 1512                     Saiman Says           hisaimansays     8.99
# 1535                 Sruthi Ravi Rio             sruthi.rav     8.91
# 1815                      RIYA GOGOI            _riyagogoi_     8.60
# 2215                 Khalid Siddiqui             khalidoon1     8.59
# 2901                   Priya Beniwal            priabeniwal     9.22
# 3275                      RIYA GOGOI            _riyagogoi_     8.60
# 3896                          Colors                 colors     8.69
# ...

# %%
nullengagement2['Followers'].plot()
# Out:
# <AxesSubplot:>

# %%
nullengagement2.plot()
# Out:
# <AxesSubplot:>

# %%
nullengagement.corr()
# Out:
#                    Q_Score  Followers  Avg_Likes  Avg_Views  Engagement_Ratio
# Q_Score           1.000000   0.306385   0.485028  -0.000833               NaN
# Followers         0.306385   1.000000   0.024420   0.901144               NaN
# Avg_Likes         0.485028   0.024420   1.000000  -0.002064               NaN
# Avg_Views        -0.000833   0.901144  -0.002064   1.000000               NaN
# Engagement_Ratio       NaN        NaN        NaN        NaN               NaN

# %%
nullengagement.describe()
# Out:
#           Q_Score     Followers   Avg_Likes     Avg_Views  Engagement_Ratio
# count  284.000000  2.840000e+02  284.000000  2.840000e+02             284.0
# mean     2.205106  4.379144e+05    0.088028  8.805143e+04               0.0
# std      0.685873  2.553085e+06    1.222289  1.265330e+06               0.0
# min      2.000000  2.000000e+04    0.000000  0.000000e+00               0.0
# 25%      2.000000  3.022500e+04    0.000000  0.000000e+00               0.0
# 50%      2.000000  4.810000e+04    0.000000  0.000000e+00               0.0
# 75%      2.000000  1.317000e+05    0.000000  1.100000e+03               0.0
# max      7.910000  3.870000e+07   20.000000  2.130000e+07               0.0

# %%
nullineng_likes=nullengagement[nullengagement['Avg_Likes']==0]
nullineng_likes
# Out:
#          Name_of_Influencer         Insta_Handle  Q_Score  Followers  \
# 58            Ileana D'Cruz      ileana_official     7.13   14800000
# 119         Krystle D'souza        krystledsouza     6.12    7500000
# 246           Poonam Pandey        ipoonampandey     2.00    3700000
# 262              Ravi Dubey        ravidubey2312     5.54    3500000
# 328        Rithvik Dhanjani            rithvik_d     4.54    2800000
# ...                     ...                  ...      ...        ...
# 6437        Aurakasihlovers             amoresfa     2.00      21200
# 6456           Meaty Mumbai          meatymumbai     2.00      20700
# 6470             Mehak Jain       myclumsycloset     2.00      20500
# 6480  VADODARA FOOD BLOGGER  foodies.of.vadodara     2.00      20300
# 6493        The Mumbai Vibe        kathleenmurze     2.00      20100
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# 58            0     405700               0.0      India
# ...

# %%
nullineng_views=nullengagement[nullengagement['Avg_Views']==0]
nullineng_views
# Out:
#          Name_of_Influencer         Insta_Handle  Q_Score  Followers  \
# 246           Poonam Pandey        ipoonampandey      2.0    3700000
# 517             Shael Oswal          singershael      2.0    1600000
# 595         Filmymantra.com          filmymantra      2.0    1300000
# 952        Ibrahim Ali Khan           iakpataudi      2.0     618500
# 1005            Barun Sobti       barunsobtisays      2.0     561000
# ...                     ...                  ...      ...        ...
# 6437        Aurakasihlovers             amoresfa      2.0      21200
# 6456           Meaty Mumbai          meatymumbai      2.0      20700
# 6470             Mehak Jain       myclumsycloset      2.0      20500
# 6480  VADODARA FOOD BLOGGER  foodies.of.vadodara      2.0      20300
# 6493        The Mumbai Vibe        kathleenmurze      2.0      20100
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# 246           0          0               0.0     Mumbai
# ...

# %%
nullineng_qscore=nullengagement[nullengagement['Q_Score']==0.0]
nullineng_qscore
# Out:
# Empty DataFrame
# Columns: [Name_of_Influencer, Insta_Handle, Q_Score, Followers, Avg_Likes, Avg_Views, Engagement_Ratio, Location, Categories]
# Index: []

# %%
nullineng_followers=nullengagement[nullengagement['Followers']==0]
nullineng_followers
# Out:
# Empty DataFrame
# Columns: [Name_of_Influencer, Insta_Handle, Q_Score, Followers, Avg_Likes, Avg_Views, Engagement_Ratio, Location, Categories]
# Index: []

# %% [markdown]
# **So as from above we clearly see in total 284 null engagement ratio there are 282 Avg_Likes are null and 184 Avg_Views are null and all others value are not null then also engagement raio is 0 means engagement ratio is more biases or dependent on these two factors.**

# %% [markdown]
# **Now we will categorize the data**

# %%
df
# Out:
#          Name_of_Influencer     Insta_Handle  Q_Score  Followers  Avg_Likes  \
# 0     Priyanka Chopra Jonas   priyankachopra     9.51   79900000    1300000
# 1           Shraddha Kapoor   shraddhakapoor     9.46   73300000    1100000
# 2               Neha Kakkar       nehakakkar     9.34   70300000     609000
# 3          Deepika Padukone  deepikapadukone     9.45   67700000    1000000
# 4                Alia Bhatt       aliaabhatt     9.99   66700000    3200000
# ...                     ...              ...      ...        ...        ...
# 6496            Ali Berrada      ali_berrada     5.32      20000        112
# 6497          Apsara Mishra     apsaramishra     4.13      20000         38
# 6498         Anagha Godbole     saffrontouch     5.76      20000        158
# 6499          True Elements    true.elements     5.66      20000        154
# 6500             Kishu Jain      retardchick     7.28      20000        785
#
# ...

# %%
qscore=df[df['Q_Score']>=5.00]
qscore
# Out:
#          Name_of_Influencer          Insta_Handle  Q_Score  Followers  \
# 0     Priyanka Chopra Jonas        priyankachopra     9.51   79900000
# 1           Shraddha Kapoor        shraddhakapoor     9.46   73300000
# 2               Neha Kakkar            nehakakkar     9.34   70300000
# 3          Deepika Padukone       deepikapadukone     9.45   67700000
# 4                Alia Bhatt            aliaabhatt     9.99   66700000
# ...                     ...                   ...      ...        ...
# 6495       Radhika Malhotra  sugarnspicebyradhika     6.91      20100
# 6496            Ali Berrada           ali_berrada     5.32      20000
# 6498         Anagha Godbole          saffrontouch     5.76      20000
# 6499          True Elements         true.elements     5.66      20000
# 6500             Kishu Jain           retardchick     7.28      20000
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# 0       1300000    3600000              1.61      India
# ...

# %%
qscore1=df[df['Q_Score']>=9.00]
qscore1
# Out:
#          Name_of_Influencer     Insta_Handle  Q_Score  Followers  Avg_Likes  \
# 0     Priyanka Chopra Jonas   priyankachopra     9.51   79900000    1300000
# 1           Shraddha Kapoor   shraddhakapoor     9.46   73300000    1100000
# 2               Neha Kakkar       nehakakkar     9.34   70300000     609000
# 3          Deepika Padukone  deepikapadukone     9.45   67700000    1000000
# 4                Alia Bhatt       aliaabhatt     9.99   66700000    3200000
# ...                     ...              ...      ...        ...        ...
# 4335                    MSK        msk_s1991     9.20     430500      56800
# 4342        Kevin Almasifar   kevinalmasifar     9.06     422700      43000
# 4355              Amul.coop       amul_india     9.11     402800      45800
# 4445          Saket Gokhale     saketgokhale     9.20     295400      62900
# 4507              FactTechz        facttechz     9.10     239500      44500
#
# ...

# %%
eng=qscore1[qscore1['Engagement_Ratio']>=5.00]
eng
# Out:
#         Name_of_Influencer            Insta_Handle  Q_Score  Followers  \
# 27       Rashmika Mandanna       rashmika_mandanna     9.79   32100000
# 29          Shah Rukh Khan                  iamsrk     9.70   30000000
# 36    Samantha Ruth Prabhu  samantharuthprabhuoffl     9.56   24100000
# 48              Allu Arjun         alluarjunonline     9.59   18500000
# 54                   Fgdfg             carryminati     9.56   15900000
# ...                    ...                     ...      ...        ...
# 4335                   MSK               msk_s1991     9.20     430500
# 4342       Kevin Almasifar          kevinalmasifar     9.06     422700
# 4355             Amul.coop              amul_india     9.11     402800
# 4445         Saket Gokhale            saketgokhale     9.20     295400
# 4507             FactTechz               facttechz     9.10     239500
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# 27      2400000    3700000              7.40  Bengaluru
# ...

# %%
qscore2=df[df['Q_Score']>=8.00]
qscore2
# Out:
#          Name_of_Influencer         Insta_Handle  Q_Score  Followers  \
# 0     Priyanka Chopra Jonas       priyankachopra     9.51   79900000
# 1           Shraddha Kapoor       shraddhakapoor     9.46   73300000
# 2               Neha Kakkar           nehakakkar     9.34   70300000
# 3          Deepika Padukone      deepikapadukone     9.45   67700000
# 4                Alia Bhatt           aliaabhatt     9.99   66700000
# ...                     ...                  ...      ...        ...
# 5870                   TNCA          tncacricket     8.15      36500
# 5877             BharatBenz           bharatbenz     8.07      36300
# 5977          Deepanshu Raj         iqlipse_nova     8.01      32900
# 5995                   Soch         mohak.mangal     8.10      31900
# 6449   Sunfeast DarkFantasy  sunfeastdarkfantasy     8.71      21000
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# 0       1300000    3600000              1.61      India
# ...

# %%
eng1=qscore2[qscore2['Engagement_Ratio']>=4.00]
eng1
# Out:
#         Name_of_Influencer            Insta_Handle  Q_Score  Followers  \
# 4               Alia Bhatt              aliaabhatt     9.99   66700000
# 27       Rashmika Mandanna       rashmika_mandanna     9.79   32100000
# 29          Shah Rukh Khan                  iamsrk     9.70   30000000
# 36    Samantha Ruth Prabhu  samantharuthprabhuoffl     9.56   24100000
# 39          Kajal Aggarwal   kajalaggarwalofficial     9.47   23100000
# ...                    ...                     ...      ...        ...
# 5870                  TNCA             tncacricket     8.15      36500
# 5877            BharatBenz              bharatbenz     8.07      36300
# 5977         Deepanshu Raj            iqlipse_nova     8.01      32900
# 5995                  Soch            mohak.mangal     8.10      31900
# 6449  Sunfeast DarkFantasy     sunfeastdarkfantasy     8.71      21000
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# 4       3200000    4800000              4.77      India
# ...

# %%
eng1=qscore2[qscore2['Followers']>=1000000]
eng1
# Out:
#          Name_of_Influencer        Insta_Handle  Q_Score  Followers  \
# 0     Priyanka Chopra Jonas      priyankachopra     9.51   79900000
# 1           Shraddha Kapoor      shraddhakapoor     9.46   73300000
# 2               Neha Kakkar          nehakakkar     9.34   70300000
# 3          Deepika Padukone     deepikapadukone     9.45   67700000
# 4                Alia Bhatt          aliaabhatt     9.99   66700000
# ...                     ...                 ...      ...        ...
# 4171    Brajesh Kumar Singh     brajeshofficial     8.48    1000000
# 4172        Prafull Billore  prafullmbachaiwala     9.14    1000000
# 4173                 Shenaz      shenaztreasury     8.55    1000000
# 4175            Gurdas Maan     gurdasmaanjeeyo     8.62    1000000
# 4176            Anil Kumble         anil.kumble     8.68    1000000
#
#       Avg_Likes  Avg_Views  Engagement_Ratio   Location  \
# 0       1300000    3600000              1.61      India
# ...

# %%
location=df

# %%
location
# Out:
#          Name_of_Influencer     Insta_Handle  Q_Score  Followers  Avg_Likes  \
# 0     Priyanka Chopra Jonas   priyankachopra     9.51   79900000    1300000
# 1           Shraddha Kapoor   shraddhakapoor     9.46   73300000    1100000
# 2               Neha Kakkar       nehakakkar     9.34   70300000     609000
# 3          Deepika Padukone  deepikapadukone     9.45   67700000    1000000
# 4                Alia Bhatt       aliaabhatt     9.99   66700000    3200000
# ...                     ...              ...      ...        ...        ...
# 6496            Ali Berrada      ali_berrada     5.32      20000        112
# 6497          Apsara Mishra     apsaramishra     4.13      20000         38
# 6498         Anagha Godbole     saffrontouch     5.76      20000        158
# 6499          True Elements    true.elements     5.66      20000        154
# 6500             Kishu Jain      retardchick     7.28      20000        785
#
# ...

# %%
location['Location'].value_counts()
# Out:
# India        1905
# Mumbai       1559
# Delhi         480
# New Delhi     427
# Bengaluru     363
#              ...
# Silchar         1
# Palakkad        1
# Addanki         1
# Vesava          1
# Solapur         1
# Name: Location, Length: 207, dtype: int64

# %%
location1=location[location['Location']=='India']
location1
# Out:
#          Name_of_Influencer               Insta_Handle  Q_Score  Followers  \
# 0     Priyanka Chopra Jonas             priyankachopra     9.51   79900000
# 1           Shraddha Kapoor             shraddhakapoor     9.46   73300000
# 3          Deepika Padukone            deepikapadukone     9.45   67700000
# 4                Alia Bhatt                 aliaabhatt     9.99   66700000
# 5              Katrina Kaif                katrinakaif     9.75   65400000
# ...                     ...                        ...      ...        ...
# 6481          Neha Malhotra  tinylovephotographybyneha     3.81      20300
# 6485         Doruk Canbilen                     dorukc     5.52      20200
# 6487       SAMRAT SHUKLA ??          samratkipathshala     7.71      20100
# 6492          Wishingmirror           thewishingmirror     6.12      20100
# 6496            Ali Berrada                ali_berrada     5.32      20000
#
#       Avg_Likes  Avg_Views  Engagement_Ratio Location  \
# ...

# %%
location2=location[location['Location']=='Mumbai']
location2
# Out:
#      Name_of_Influencer      Insta_Handle  Q_Score  Followers  Avg_Likes  \
# 2           Neha Kakkar        nehakakkar     9.34   70300000     609000
# 14       Hrithik Roshan     hrithikroshan     9.61   43300000    1700000
# 21     Parineeti Chopra   parineetichopra     9.26   36800000     303200
# 24         Sonam Kapoor       sonamkapoor     9.24   32900000     211800
# 29       Shah Rukh Khan            iamsrk     9.70   30000000    2000000
# ...                 ...               ...      ...        ...        ...
# 6473    Mad About Bappa   mad_about_bappa     7.28      20400        800
# 6483              CSMVS       csmvsmumbai     5.71      20300        162
# 6488     Anshul Keswani  the.carving.lens     7.61      20100       1100
# 6493    The Mumbai Vibe     kathleenmurze     2.00      20100          0
# 6497      Apsara Mishra      apsaramishra     4.13      20000         38
#
#       Avg_Views  Engagement_Ratio Location                       Categories
# ...

# %%
location3=location2[location2['Followers']<=100000]
location3
# Out:
#             Name_of_Influencer      Insta_Handle  Q_Score  Followers  \
# 1810              Vinod Channa    thevinodchanna     5.72     100000
# 1811            Jaaved Jaaferi     jaavedjaaferi     7.77      99600
# 1812               Jyoti Bohra      jyotibohraaa     6.98      99600
# 1813  Kayaan Shiraz Contractor  kayaancontractor     6.33      99500
# 1815                RIYA GOGOI       _riyagogoi_     8.60      99200
# ...                        ...               ...      ...        ...
# 6473           Mad About Bappa   mad_about_bappa     7.28      20400
# 6483                     CSMVS       csmvsmumbai     5.71      20300
# 6488            Anshul Keswani  the.carving.lens     7.61      20100
# 6493           The Mumbai Vibe     kathleenmurze     2.00      20100
# 6497             Apsara Mishra      apsaramishra     4.13      20000
#
#       Avg_Likes  Avg_Views  Engagement_Ratio Location  \
# 1810        164       4700              0.17   Mumbai
# ...

# %%
location3.tail(15)
# Out:
#                 Name_of_Influencer         Insta_Handle  Q_Score  Followers  \
# 6421  PHOTOGRAPHER / MUMBAI /INDIA       photokatamasha     3.44      21500
# 6423                 Mumbai Munch         mumbai_munch     4.84      21500
# 6428                   Saloni Shah   saloni.thesobogirl     7.44      21400
# 6433                Nilanjana Naha    nilanjanaofficial     6.39      21300
# 6435     M A Y U R   A G R A W A L           metal_baba     2.72      21300
# 6439                      Anitaa??     anitaapemgirikar     7.60      21200
# 6440            Chef Pallavi Nigam  pallavi_nigam_sahay     4.18      21100
# 6448           Photo Tips By Shari        shari_academy     6.20      21000
# 6456                  Meaty Mumbai          meatymumbai     2.00      20700
# 6464        Kopana Football School       kopanafootball     5.13      20600
# 6473               Mad About Bappa      mad_about_bappa     7.28      20400
# ...

# %%
location4=location3['Categories'].value_counts()
location4
# Out:
# Arts & EntertainmentMovies             130
# Food & Drink                            80
# LifestyleStyle & Fashion                51
# Style & FashionClothing                 44
# Style & FashionBeauty                   33
#                                       ...
# Family & ParentingBeauty                 1
# FitnessYoga                              1
# Family & ParentingHealth & Wellness      1
# TravelFamily & Parenting                 1
# TechnologyGraphics & Animation           1
# Name: Categories, Length: 81, dtype: int64

# %%
location5=location3[location3['Categories']=='Food & Drink']
location5
# Out:
#       Name_of_Influencer         Insta_Handle  Q_Score  Followers  Avg_Likes  \
# 5049    Mumbai Nightlife     mumbai.nightlife     6.39      96900        346
# 5100    MumbaiFoodicious     mumbaifoodicious     4.86      90800         78
# 5124       Nishant Patel            indieopus     2.24      88800          0
# 5137         Amrita Kaur         amritaoflife     2.80      87000          0
# 5152              Ayushi    the_foodiediaries     5.77      86100        159
# ...                  ...                  ...      ...        ...        ...
# 6423       Mumbai Munch         mumbai_munch     4.84      21500         77
# 6428         Saloni Shah   saloni.thesobogirl     7.44      21400        891
# 6440  Chef Pallavi Nigam  pallavi_nigam_sahay     4.18      21100         40
# 6456        Meaty Mumbai          meatymumbai     2.00      20700          0
# 6493     The Mumbai Vibe        kathleenmurze     2.00      20100          0
#
# ...

# %%
eng2=location5[location5['Engagement_Ratio']>=4.00]
eng2
# Out:
#               Name_of_Influencer        Insta_Handle  Q_Score  Followers  \
# 6056  Zainab #FoodTravelExplorer     zainabcookhouse     7.75      30600
# 6428                 Saloni Shah  saloni.thesobogirl     7.44      21400
#
#       Avg_Likes  Avg_Views  Engagement_Ratio Location    Categories
# 6056       2700        156              8.90   Mumbai  Food & Drink
# 6428        891       1700              4.21   Mumbai  Food & Drink

# %%
eng3=location5[location5['Engagement_Ratio']>=3.00]
eng3
# Out:
#                     Name_of_Influencer        Insta_Handle  Q_Score  \
# 5350  Ritika Betala | Foodies Of India      foodiesofindia     7.69
# 5777                    Shreya Sanghvi         theunoplate     7.61
# 5814                Sucheta Chatterjee        yummyalldays     7.63
# 5954                       TheForkplay         theforkplay     7.61
# 6056        Zainab #FoodTravelExplorer     zainabcookhouse     7.75
# 6428                       Saloni Shah  saloni.thesobogirl     7.44
#
#       Followers  Avg_Likes  Avg_Views  Engagement_Ratio Location    Categories
# 5350      64300       2000      10800              3.20   Mumbai  Food & Drink
# 5777      39500       1200       2800              3.05   Mumbai  Food & Drink
# 5814      38100       1300        351              3.73   Mumbai  Food & Drink
# 5954      34000       1200       4800              3.44   Mumbai  Food & Drink
# 6056      30600       2700        156              8.90   Mumbai  Food & Drink
# ...

# %%
eng3.corr()
# Out:
#                    Q_Score  Followers  Avg_Likes  Avg_Views  Engagement_Ratio
# Q_Score           1.000000   0.517128   0.865428   0.174322          0.473239
# Followers         0.517128   1.000000   0.311251   0.833228         -0.372406
# Avg_Likes         0.865428   0.311251   1.000000   0.089401          0.763299
# Avg_Views         0.174322   0.833228   0.089401   1.000000         -0.485596
# Engagement_Ratio  0.473239  -0.372406   0.763299  -0.485596          1.000000
