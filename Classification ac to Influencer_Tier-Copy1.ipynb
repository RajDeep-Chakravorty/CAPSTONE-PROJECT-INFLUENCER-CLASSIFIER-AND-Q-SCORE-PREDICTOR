# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#to ignore all the warnings
import warnings 
warnings.filterwarnings("ignore")

# %%
#reading the csv file
df = pd.read_csv('Final.csv',encoding_errors= 'replace')

# %%
df
# Out:
#      Name_of_Influencer          Insta_Handle  Q_Score  Followers  Avg_Likes  \
# 0            Kishu Jain           retardchick     7.28      20000      785.0
# 1            Tia Bajpai             tiabajpai     9.03    4700000    41800.0
# 2            Aamir Khan            _aamirkhan     9.25    3600000   267300.0
# 3                Funcho                funcho     9.24    2300000   223300.0
# 4            Upen Patel        upenpatelworld     8.83    2100000    31400.0
# ...                 ...                   ...      ...        ...        ...
# 6291   Radhika Malhotra  sugarnspicebyradhika     6.91      20100      558.0
# 6292        Ali Berrada           ali_berrada     5.32      20000      112.0
# 6293      Apsara Mishra          apsaramishra     4.13      20000       38.0
# 6294     Anagha Godbole          saffrontouch     5.76      20000      158.0
# 6295      True Elements         true.elements     5.66      20000      154.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6296 entries, 0 to 6295
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name_of_Influencer  6296 non-null   object
#  1   Insta_Handle        6296 non-null   object
#  2   Q_Score             6296 non-null   float64
#  3   Followers           6296 non-null   int64
#  4   Avg_Likes           6296 non-null   float64
#  5   Avg_Views           6296 non-null   float64
#  6   Engagement_Ratio    6296 non-null   float64
#  7   Location            6296 non-null   object
#  8   Categories          6296 non-null   object
#  9   Influencer_Tier     6296 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 492.0+ KB

# %%
df.isna().sum()
# Out:
# Name_of_Influencer    0
# Insta_Handle          0
# Q_Score               0
# Followers             0
# Avg_Likes             0
# Avg_Views             0
# Engagement_Ratio      0
# Location              0
# Categories            0
# Influencer_Tier       0
# dtype: int64

# %%
df.shape
# Out:
# (6296, 10)

# %%
df.describe()
# Out:
#            Q_Score     Followers     Avg_Likes     Avg_Views  Engagement_Ratio
# count  6296.000000  6.296000e+03  6.296000e+03  6.296000e+03       6296.000000
# mean      7.002184  9.712887e+05  2.536096e+04  7.924264e+04          2.201711
# std       1.749964  4.796833e+06  1.230814e+05  3.740428e+05          3.603434
# min       2.000000  2.000000e+04  2.000000e+00  1.176000e+01          0.000000
# 25%       6.130000  4.460000e+04  3.500000e+02  2.700000e+03          0.360000
# 50%       7.620000  1.135000e+05  1.500000e+03  1.118600e+04          1.160000
# 75%       8.140000  4.617250e+05  7.688000e+03  4.402500e+04          2.780000
# max      10.000000  2.043000e+08  3.300000e+06  2.130000e+07        122.400000

# %%
df['Name_of_Influencer'].value_counts()
# Out:
# Travel                        42
# Photography                   39
# Fitness                       12
# Lifestyle                     10
# Music                          9
#                               ..
# Garima Jain                    1
# Lokesh Gurjar                  1
# ( OFFICIAL PANJAB_MEDIA) �     1
# Micset                         1
# True Elements                  1
# Name: Name_of_Influencer, Length: 5725, dtype: int64

# %%
df.nunique()
# Out:
# Name_of_Influencer    5725
# Insta_Handle          5744
# Q_Score                538
# Followers             2628
# Avg_Likes             1926
# Avg_Views             2098
# Engagement_Ratio       917
# Location               203
# Categories              14
# Influencer_Tier          4
# dtype: int64

# %%
df['Influencer_Tier'].value_counts()
# Out:
# Micro        2828
# Mid Tier     1934
# Mega         1304
# Celebrity     230
# Name: Influencer_Tier, dtype: int64

# %%
df
# Out:
#      Name_of_Influencer          Insta_Handle  Q_Score  Followers  Avg_Likes  \
# 0            Kishu Jain           retardchick     7.28      20000      785.0
# 1            Tia Bajpai             tiabajpai     9.03    4700000    41800.0
# 2            Aamir Khan            _aamirkhan     9.25    3600000   267300.0
# 3                Funcho                funcho     9.24    2300000   223300.0
# 4            Upen Patel        upenpatelworld     8.83    2100000    31400.0
# ...                 ...                   ...      ...        ...        ...
# 6291   Radhika Malhotra  sugarnspicebyradhika     6.91      20100      558.0
# 6292        Ali Berrada           ali_berrada     5.32      20000      112.0
# 6293      Apsara Mishra          apsaramishra     4.13      20000       38.0
# 6294     Anagha Godbole          saffrontouch     5.76      20000      158.0
# 6295      True Elements         true.elements     5.66      20000      154.0
#
# ...

# %% [markdown]
# # Univariate Analysis

# %%
#taking all the columns where values are continous
contdf = df[['Q_Score','Followers','Avg_Likes','Avg_Views','Engagement_Ratio']]

# %%
from scipy.stats import skew,kurtosis
key =[]
skewval =[]
kurtval =[]
for i  in contdf:
    print('The skewness of the ',i, '=',skew(contdf[i]))
    print('The kurtosis of the ',i, '=',kurtosis(contdf[i]))
    plt.figure()
    sns.distplot(contdf[i],color='blue',kde=True,
                 hist_kws = {'color':'green', 'edgecolor':'black','linewidth':2,'alpha':0.9})
    plt.show()
    key.append(i)
    skewval.append(skew(contdf[i]))
    kurtval.append(kurtosis(contdf[i]))
# Out:
# The skewness of the  Q_Score = -1.0264918134596808
# The kurtosis of the  Q_Score = 0.5020292696001745
# The skewness of the  Followers = 18.683321776574555
# The kurtosis of the  Followers = 586.8944342727438
# The skewness of the  Avg_Likes = 13.076612337358153
# The kurtosis of the  Avg_Likes = 240.79141056556688
# The skewness of the  Avg_Views = 32.083609935990246
# The kurtosis of the  Avg_Views = 1669.6644378206047
# The skewness of the  Engagement_Ratio = 10.986939808222237
# The kurtosis of the  Engagement_Ratio = 279.15250319320296

# %%
from scipy.stats import shapiro
shapiro(contdf)
# Out:
# ShapiroResult(statistic=0.06120985746383667, pvalue=0.0)

# %% [markdown]
# **Since the p-value is 0.0 which is less than the alpha(0.5) then we reject the null hypothesis i.e. we have sufficient evidence to say that sample does not come from a normal distribution which is also pretty clear from the above graphs**

# %%
dict = {'variables':key,'skew_values':skewval,'kurtosis_values':kurtval}

# %%
show_val = pd.DataFrame(dict)

# %%
show_val
# Out:
#           variables  skew_values  kurtosis_values
# 0           Q_Score    -1.026492         0.502029
# 1         Followers    18.683322       586.894434
# 2         Avg_Likes    13.076612       240.791411
# 3         Avg_Views    32.083610      1669.664438
# 4  Engagement_Ratio    10.986940       279.152503

# %% [markdown]
# The rule of thumb for skewness seems to be:
#
# - If the skewness is between -0.5 and 0.5, the data are fairly symmetrical
# - If the skewness is between -1 and – 0.5 or between 0.5 and 1, the data are moderately skewed
# - If the skewness is less than -1 or greater than 1, the data are highly skewed
# - If Skewness is less than 0, then it is called left-skewed or that the left tail is longer than the right tail.
# - If Skewness is more than 0, then it is called right-skewed or that the right tail is longer than the left tail.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - the kurtosis of a normal distribution is 0
# - So, if a dataset has a positive kurtosis, it has more in the tails than the normal distribution.  If a dataset has a negative kurtosis, it has less in the tails than the normal distribution.

# %%
'''#To handle the skewness of the data we let us do log transform
Followerslog =np.sqrt(contdf['Followers'])
Followerslog.skew()'''
# Out:
# "#To handle the skewness of the data we let us do log transform\nFollowerslog =np.sqrt(contdf['Followers'])\nFollowerslog.skew()"

# %%
'''To handle the skewness of the data we let us do log transform
Avg_Likeslog = np.log(contdf['Avg_Likes'])
Avg_Likeslog.skew()'''
# Out:
# "To handle the skewness of the data we let us do log transform\nAvg_Likeslog = np.log(contdf['Avg_Likes'])\nAvg_Likeslog.skew()"

# %%
'''#for checking of outliers, plotting the boxplot for each continous column
for i  in contdf:
    plt.figure()
    sns.boxplot(contdf[i],color='blue')
    plt.show()'''
# Out:
# "#for checking of outliers, plotting the boxplot for each continous column\nfor i  in contdf:\n    plt.figure()\n    sns.boxplot(contdf[i],color='blue')\n    plt.show()"

# %%
df
# Out:
#      Name_of_Influencer          Insta_Handle  Q_Score  Followers  Avg_Likes  \
# 0            Kishu Jain           retardchick     7.28      20000      785.0
# 1            Tia Bajpai             tiabajpai     9.03    4700000    41800.0
# 2            Aamir Khan            _aamirkhan     9.25    3600000   267300.0
# 3                Funcho                funcho     9.24    2300000   223300.0
# 4            Upen Patel        upenpatelworld     8.83    2100000    31400.0
# ...                 ...                   ...      ...        ...        ...
# 6291   Radhika Malhotra  sugarnspicebyradhika     6.91      20100      558.0
# 6292        Ali Berrada           ali_berrada     5.32      20000      112.0
# 6293      Apsara Mishra          apsaramishra     4.13      20000       38.0
# 6294     Anagha Godbole          saffrontouch     5.76      20000      158.0
# 6295      True Elements         true.elements     5.66      20000      154.0
#
# ...

# %%
df1 = df.loc[:,['Followers','Avg_Likes','Avg_Views','Categories','Influencer_Tier','Name_of_Influencer']]

# %%
df1
# Out:
#       Followers  Avg_Likes   Avg_Views              Categories  \
# 0         20000      785.0    22427.45              Technology
# 1       4700000    41800.0   439736.00  Arts and Entertainment
# 2       3600000   267300.0  2811996.00  Arts and Entertainment
# 3       2300000   223300.0  2349116.00  Arts and Entertainment
# 4       2100000    31400.0   330328.00  Arts and Entertainment
# ...         ...        ...         ...                     ...
# 6291      20100      558.0     4500.00          Food and Drink
# 6292      20000      112.0      649.00                  Travel
# 6293      20000       38.0      525.00   Lifestyle and Fashion
# 6294      20000      158.0     2300.00          Food and Drink
# 6295      20000      154.0      393.00          Food and Drink
#
#      Influencer_Tier Name_of_Influencer
# 0          Celebrity         Kishu Jain
# 1               Mega         Tia Bajpai
# 2               Mega         Aamir Khan
# 3               Mega             Funcho
# ...

# %%
df2 = df1
df2
# Out:
#       Followers  Avg_Likes   Avg_Views  Categories  Influencer_Tier  \
# 0         20000      785.0    22427.45          12                0
# 1       4700000    41800.0   439736.00           0                1
# 2       3600000   267300.0  2811996.00           0                1
# 3       2300000   223300.0  2349116.00           0                1
# 4       2100000    31400.0   330328.00           0                1
# ...         ...        ...         ...         ...              ...
# 6291      20100      558.0     4500.00           5                2
# 6292      20000      112.0      649.00          13                0
# 6293      20000       38.0      525.00           8                0
# 6294      20000      158.0     2300.00           5                0
# 6295      20000      154.0      393.00           5                0
#
#       Influencer_Id
# 0              2334
# 1              5249
# 2               168
# 3              1600
# 4              5351
# ...             ...
# ...

# %%
df1['Influencer_Tier'].value_counts()
# Out:
# Micro        2828
# Mid Tier     1934
# Mega         1304
# Celebrity     230
# Name: Influencer_Tier, dtype: int64

# %%
#Label Encoding
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df1['Categories']= label_encoder.fit_transform(df1['Categories'])
df1['Influencer_Tier']= label_encoder.fit_transform(df1['Influencer_Tier'])
df1['Name_of_Influencer']= label_encoder.fit_transform(df1['Name_of_Influencer'])

# %%
df1 = df1.rename(columns={'Name_of_Influencer': 'Influencer_Id'})

# %%
df1
# Out:
#       Followers  Avg_Likes   Avg_Views  Categories  Influencer_Tier  \
# 0         20000      785.0    22427.45          12                0
# 1       4700000    41800.0   439736.00           0                1
# 2       3600000   267300.0  2811996.00           0                1
# 3       2300000   223300.0  2349116.00           0                1
# 4       2100000    31400.0   330328.00           0                1
# ...         ...        ...         ...         ...              ...
# 6291      20100      558.0     4500.00           5                2
# 6292      20000      112.0      649.00          13                0
# 6293      20000       38.0      525.00           8                0
# 6294      20000      158.0     2300.00           5                0
# 6295      20000      154.0      393.00           5                0
#
#       Influencer_Id
# 0              2334
# 1              5249
# 2               168
# 3              1600
# 4              5351
# ...             ...
# ...

# %%
concatenated_column = pd.concat([df1['Influencer_Id'], df['Name_of_Influencer']], axis=1)
concatenated_column
# Out:
#       Influencer_Id Name_of_Influencer
# 0              2334         Kishu Jain
# 1              5249         Tia Bajpai
# 2               168         Aamir Khan
# 3              1600             Funcho
# 4              5351         Upen Patel
# ...             ...                ...
# 6291           3692   Radhika Malhotra
# 6292            385        Ali Berrada
# 6293            637      Apsara Mishra
# 6294            474     Anagha Godbole
# 6295           5298      True Elements
#
# [6296 rows x 2 columns]

# %%
concatenated_column.to_csv("Influencer Id List.csv",index=False)

# %%
df1['Influencer_Tier'].dtypes
# Out:
# dtype('O')

# %%
#defining dependent and independent variables
X = df1.drop('Influencer_Tier', axis=1)
y = df1['Influencer_Tier']

# %%
#splitting data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4722, 5), (1574, 5), (4722,), (1574,))

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
df[['Followers','Avg_Likes','Avg_Views']] = ms.fit_transform(df[['Followers','Avg_Likes','Avg_Views']])

# %%
#training model
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)

#getting confusion matrix
from sklearn.metrics import confusion_matrix,classification_report
y_pred = lr.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)

#checking accuracy
from sklearn.metrics import accuracy_score
lr_acc = accuracy_score(y_test,y_pred)
print('\nAccuracy score = ',round(lr_acc*100,2),'%')
# Out:
# confusion matrix:
#  [[ 26  27   3   0]
#  [ 24 249   0  45]
#  [  1  58 592  65]
#  [  3 166 193 122]]
#
# Accuracy score =  62.83 %

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion = 'entropy')
dt.fit(X_train,y_train)

#getting confusion matrix
from sklearn.metrics import confusion_matrix,classification_report
y_pred = dt.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)

#checking accuracy
from sklearn.metrics import accuracy_score
dt_acc = accuracy_score(y_test,y_pred)
print('\nAccuracy score = ',round(dt_acc*100,2),'%')
# Out:
# confusion matrix:
#  [[ 56   0   0   0]
#  [  0 317   0   1]
#  [  0   0 716   0]
#  [  0   0   0 484]]
#
# Accuracy score =  99.94 %

# %%
#training model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 60, criterion = 'entropy',random_state = 1)
rf.fit(X_train,y_train)

#getting confusion matrix
from sklearn.metrics import confusion_matrix,classification_report
y_pred = rf.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
print('confusion matrix:\n',cm)

#checking accuracy
from sklearn.metrics import accuracy_score
rf_acc = accuracy_score(y_test,y_pred)
print('\nAccuracy score = ',round(rf_acc*100,2),'%')
# Out:
# confusion matrix:
#  [[ 55   0   0   1]
#  [  0 318   0   0]
#  [  0   0 716   0]
#  [  0   0   0 484]]
#
# Accuracy score =  99.94 %

# %%
### Create a Pickle file using serialization 
import pickle
pickle_out = open("classification.pkl","wb")
pickle.dump(rf, pickle_out)
pickle_out.close()
